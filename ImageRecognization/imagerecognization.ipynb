# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulvenkat207/Data-Exploration/blob/main/ImageRecognization/imagerecognization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/imageRecognization'

# %%
categories = ['rugby ball', 'soccer ball', 'volley ball']
selected_images = []

# Iterate over categories
for category in categories:
    category_path = os.path.join(path, category)
    images = os.listdir(category_path)
    # Take 10 random images from each category
    selected_images.extend([(os.path.join(category_path, image), category) for image in random.sample(images, 10)])

# Shuffle the selected images
random.shuffle(selected_images)

# Print image IDs and class names for the first 10 images
for image_path, class_name in selected_images[:10]:
    image_id = os.path.basename(image_path).split('.')[0]
    print(f"Image ID: {image_id}, Class Name: {class_name}")

# Display the selected and shuffled images one after the other
plt.figure(figsize=(15, 6))
for image_path, class_name in selected_images[:10]:
    img = Image.open(image_path)

    plt.imshow(img)
    plt.title(class_name)
    plt.axis('off')

    # Add a little pause between displaying images
    plt.pause(1)  # Adjust the pause duration as needed

plt.show()
# Out:
# Image ID: n04118538_2481, Class Name: rugby ball
# Image ID: n04254680_9595, Class Name: soccer ball
# Image ID: n04118538_7114, Class Name: rugby ball
# Image ID: n04540053_10237, Class Name: volley ball
# Image ID: n04540053_10217, Class Name: volley ball
# Image ID: n04540053_10123, Class Name: volley ball
# Image ID: n04118538_3551, Class Name: rugby ball
# Image ID: n04254680_10169, Class Name: soccer ball
# Image ID: n04540053_10054, Class Name: volley ball
# Image ID: n04540053_10284, Class Name: volley ball
